# %%
import numpy as np # calculation
import pandas as pd # Excel for Python
import datetime as dt # allow for date and time series manipulation
import seaborn as sns # a charting package
import matplotlib.pyplot as plt # the original Python chating package
from datetime import datetime, timedelta
#a `magic code` that allows ploting of charts within the notebook/
# %matplotlib inline

# %%
df=pd.read_csv('/content/Cohort base MAY 2021-made in JUNE  (1).csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178053 entries, 0 to 178052
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   trainer_ID             178053 non-null  int64
#  1   trainee_ID             178053 non-null  int64
#  2   DATE(tran_date)        178053 non-null  object
#  3   DATE(assign_date)      178053 non-null  object
#  4   DATE(assign_end_date)  178053 non-null  object
#  5   pack_id                178053 non-null  int64
#  6   pack_price             178053 non-null  float64
#  7   tran_flag              178053 non-null  object
#  8   status                 178053 non-null  int64
#  9   status_change          178053 non-null  int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 13.6+ MB

# %%
df
# Out:
#         trainer_ID  trainee_ID DATE(tran_date)  ... tran_flag status  status_change
# 0             1545       30995      2017-04-01  ...         I      1              1
# 1             1537       28443      2017-04-01  ...         I      1              1
# 2              117       31054      2017-04-01  ...         I      1              1
# 3              562       32095      2017-04-01  ...         I      1              1
# 4              562       17351      2017-04-01  ...         R      1              1
# ...            ...         ...             ...  ...       ...    ...            ...
# 178048         118      101909      2021-06-07  ...         R      0              0
# 178049        2296      533479      2021-06-07  ...         R      0              0
# 178050        2731      972010      2021-06-07  ...         I      0              0
# 178051         118      256224      2021-06-07  ...         R      0              0
# ...

# %%
df['DATE(tran_date)']=pd.to_datetime(df['DATE(tran_date)'])
df['DATE(tran_date)']=pd.to_datetime(df['DATE(tran_date)'],format='%d-%m-%Y')

# %%
df
# Out:
#         trainer_ID  trainee_ID DATE(tran_date)  ... tran_flag status  status_change
# 0             1545       30995      2017-04-01  ...         I      1              1
# 1             1537       28443      2017-04-01  ...         I      1              1
# 2              117       31054      2017-04-01  ...         I      1              1
# 3              562       32095      2017-04-01  ...         I      1              1
# 4              562       17351      2017-04-01  ...         R      1              1
# ...            ...         ...             ...  ...       ...    ...            ...
# 178048         118      101909      2021-06-07  ...         R      0              0
# 178049        2296      533479      2021-06-07  ...         R      0              0
# 178050        2731      972010      2021-06-07  ...         I      0              0
# 178051         118      256224      2021-06-07  ...         R      0              0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178053 entries, 0 to 178052
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   trainer_ID             178053 non-null  int64
#  1   trainee_ID             178053 non-null  int64
#  2   DATE(tran_date)        178053 non-null  datetime64[ns]
#  3   DATE(assign_date)      178053 non-null  object
#  4   DATE(assign_end_date)  178053 non-null  object
#  5   pack_id                178053 non-null  int64
#  6   pack_price             178053 non-null  float64
#  7   tran_flag              178053 non-null  object
#  8   status                 178053 non-null  int64
#  9   status_change          178053 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(5), object(3)
# memory usage: 13.6+ MB

# %%
df.tail(15)
# Out:
#         trainer_ID  trainee_ID DATE(tran_date)  ... tran_flag status  status_change
# 178038        2595      728029      2021-06-07  ...         R      0              0
# 178039         103      440488      2021-06-07  ...         R      0              0
# 178040        2531      943771      2021-06-07  ...         I      0              0
# 178041        2366      441737      2021-06-07  ...         I      0              0
# 178042        2291      272405      2021-06-07  ...         R      0              0
# 178043        2418      824325      2021-06-07  ...         R      0              0
# 178044        2560     1143869      2021-06-07  ...         I      0              0
# 178045        2491     1368501      2021-06-07  ...         I      0              0
# 178046        2569      988909      2021-06-07  ...         R      0              0
# 178047        2131     1512900      2021-06-07  ...         I      0              0
# ...

# %%
df[df['trainee_ID']==99987]
# Out:
#         trainer_ID  trainee_ID DATE(tran_date)  ... tran_flag status  status_change
# 75956         2399       99987      2019-09-11  ...         I      1              0
# 84023         2399       99987      2019-12-03  ...         R      1              0
# 93420         2399       99987      2020-02-25  ...         R      1              0
# 102029        2399       99987      2020-06-01  ...         R      1              0
# 115294        2399       99987      2020-08-26  ...         R      1              0
# 131505        2399       99987      2020-11-17  ...         R      1              0
# 149901        2399       99987      2021-02-09  ...         R      1              0
# 169556        2399       99987      2021-05-05  ...         R      0              0
#
# [8 rows x 10 columns]

# %%
df['FirstTransactionDate'] = df.groupby('trainee_ID')['DATE(tran_date)'].transform('min')

# %%
df.tail(15)
# Out:
#         trainer_ID  trainee_ID  ... status_change FirstTransactionDate
# 178038        2595      728029  ...             0           2020-11-22
# 178039         103      440488  ...             0           2020-01-22
# 178040        2531      943771  ...             0           2021-06-07
# 178041        2366      441737  ...             0           2021-06-07
# 178042        2291      272405  ...             0           2019-07-16
# 178043        2418      824325  ...             0           2020-12-08
# 178044        2560     1143869  ...             0           2021-06-07
# 178045        2491     1368501  ...             0           2021-06-07
# 178046        2569      988909  ...             0           2021-02-05
# 178047        2131     1512900  ...             0           2021-06-07
# 178048         118      101909  ...             0           2020-08-15
# 178049        2296      533479  ...             0           2020-05-07
# ...

# %%
df['YearOfFt']=df['FirstTransactionDate'].dt.year

# %%
df['MonthOfFt']=df['FirstTransactionDate'].dt.month_name()

# %%
df['Diff_in_months']=(df['DATE(tran_date)'].dt.year - df['FirstTransactionDate'].dt.year)*12 + (df['DATE(tran_date)'].dt.month - df['FirstTransactionDate'].dt.month)

# %%
df.tail(15)
# Out:
#         trainer_ID  trainee_ID  ... MonthOfFt Diff_in_months
# 178038        2595      728029  ...  November              7
# 178039         103      440488  ...   January             17
# 178040        2531      943771  ...      June              0
# 178041        2366      441737  ...      June              0
# 178042        2291      272405  ...      July             23
# 178043        2418      824325  ...  December              6
# 178044        2560     1143869  ...      June              0
# 178045        2491     1368501  ...      June              0
# 178046        2569      988909  ...  February              4
# 178047        2131     1512900  ...      June              0
# 178048         118      101909  ...    August             10
# 178049        2296      533479  ...       May             13
# 178050        2731      972010  ...      June              0
# 178051         118      256224  ...       May             13
# ...

# %%
df.to_csv('Cohort_check----11.csv',index=False)

# %%
df['Occurence'] = df.groupby('trainee_ID')['trainee_ID'].rank(method='first')

# %%
df.tail(15)
# Out:
#         trainer_ID  trainee_ID  ... Diff_in_months Occurence
# 178038        2595      728029  ...              7       3.0
# 178039         103      440488  ...             17       2.0
# 178040        2531      943771  ...              0       1.0
# 178041        2366      441737  ...              0       1.0
# 178042        2291      272405  ...             23       5.0
# 178043        2418      824325  ...              6       3.0
# 178044        2560     1143869  ...              0       1.0
# 178045        2491     1368501  ...              0       1.0
# 178046        2569      988909  ...              4       2.0
# 178047        2131     1512900  ...              0       1.0
# 178048         118      101909  ...             10       2.0
# 178049        2296      533479  ...             13       4.0
# 178050        2731      972010  ...              0       1.0
# 178051         118      256224  ...             13       3.0
# ...

# %%
df.to_csv('Cohort_check_final.csv',index=False)

# %%
pivot = df.pivot_table(index=['YearOfFt','MonthOfFt'], columns=['Diff_in_months'],values=['pack_price'], aggfunc='sum')

# %%
pivot
# Out:
#                      pack_price            ...
# Diff_in_months               0         1   ...         49        50
# YearOfFt MonthOfFt                         ...
# 2017     April      11542000.00   29000.0  ...  297109.46  101871.0
#          August     14250501.00   62000.0  ...        NaN       NaN
#          December   14634000.00   27000.0  ...        NaN       NaN
#          July       14307300.00   41000.0  ...        NaN       NaN
#          June       13457000.00   69500.0  ...        NaN       NaN
#          May        12027000.00   62000.0  ...   64644.00       NaN
#          November   15395600.00   51000.0  ...        NaN       NaN
#          October    13481500.00   15500.0  ...        NaN       NaN
#          September  14623134.28   45000.0  ...        NaN       NaN
# 2018     April      18022002.00   37000.0  ...        NaN       NaN
#          August     19550800.00   32000.0  ...        NaN       NaN
# ...

# %%
months=['January', 'February','March','April','May','June','July','August','September','October','November','December']

df_final=pivot.reindex(months,level=1)

df_final.to_csv('test4.csv',index=['YearOfFt','MonthOfFt'])

# %%
df_final
# Out:
#                      pack_price            ...
# Diff_in_months               0         1   ...         49        50
# YearOfFt MonthOfFt                         ...
# 2017     April      11542000.00   29000.0  ...  297109.46  101871.0
#          May        12027000.00   62000.0  ...   64644.00       NaN
#          June       13457000.00   69500.0  ...        NaN       NaN
#          July       14307300.00   41000.0  ...        NaN       NaN
#          August     14250501.00   62000.0  ...        NaN       NaN
#          September  14623134.28   45000.0  ...        NaN       NaN
#          October    13481500.00   15500.0  ...        NaN       NaN
#          November   15395600.00   51000.0  ...        NaN       NaN
#          December   14634000.00   27000.0  ...        NaN       NaN
# 2018     January    16132700.00    7000.0  ...        NaN       NaN
#          February   15558000.00   58000.0  ...        NaN       NaN
# ...

# %%
df_final=df_final.reset_index()

# %%
df_final
# Out:
#                YearOfFt  MonthOfFt   pack_price  ...
# Diff_in_months                                0  ...         48         49        50
# 0                  2017      April  11542000.00  ...  212570.81  297109.46  101871.0
# 1                  2017        May  12027000.00  ...  300540.44   64644.00       NaN
# 2                  2017       June  13457000.00  ...   82643.00        NaN       NaN
# 3                  2017       July  14307300.00  ...        NaN        NaN       NaN
# 4                  2017     August  14250501.00  ...        NaN        NaN       NaN
# 5                  2017  September  14623134.28  ...        NaN        NaN       NaN
# 6                  2017    October  13481500.00  ...        NaN        NaN       NaN
# 7                  2017   November  15395600.00  ...        NaN        NaN       NaN
# 8                  2017   December  14634000.00  ...        NaN        NaN       NaN
# ...

# %%
columns_1=[]
columns_1.append('Year')
columns_1.append('Month')
columns_1.append('Total')

max_value=df['Diff_in_months'].max()
print(columns_1,end='\n')
print(max_value)
# Out:
# ['Year', 'Month', 'Total']
# 50

# %%
for i in range(1, max_value+1):
  columns_1.append("M"+str(i))
columns_1
# Out:
# ['Year',
#  'Month',
#  'Total',
#  'M1',
#  'M2',
#  'M3',
#  'M4',
#  'M5',
#  'M6',
#  'M7',
#  'M8',
#  'M9',
#  'M10',
#  'M11',
#  'M12',
#  'M13',
#  'M14',
#  'M15',
#  'M16',
#  'M17',
#  'M18',
#  'M19',
#  'M20',
#  'M21',
#  'M22',
#  'M23',
#  'M24',
#  'M25',
#  'M26',
#  'M27',
#  'M28',
#  'M29',
#  'M30',
#  'M31',
#  'M32',
#  'M33',
#  'M34',
#  'M35',
#  'M36',
#  'M37',
#  'M38',
#  'M39',
#  'M40',
#  'M41',
#  'M42',
#  'M43',
#  'M44',
#  'M45',
#  'M46',
#  'M47',
#  'M48',
#  'M49',
#  'M50']

# %%
df_final.columns=[col for col in columns_1]
df_final
# Out:
#     Year      Month        Total  ...        M48        M49       M50
# 0   2017      April  11542000.00  ...  212570.81  297109.46  101871.0
# 1   2017        May  12027000.00  ...  300540.44   64644.00       NaN
# 2   2017       June  13457000.00  ...   82643.00        NaN       NaN
# 3   2017       July  14307300.00  ...        NaN        NaN       NaN
# 4   2017     August  14250501.00  ...        NaN        NaN       NaN
# 5   2017  September  14623134.28  ...        NaN        NaN       NaN
# 6   2017    October  13481500.00  ...        NaN        NaN       NaN
# 7   2017   November  15395600.00  ...        NaN        NaN       NaN
# 8   2017   December  14634000.00  ...        NaN        NaN       NaN
# 9   2018    January  16132700.00  ...        NaN        NaN       NaN
# 10  2018   February  15558000.00  ...        NaN        NaN       NaN
# 11  2018      March  17489500.00  ...        NaN        NaN       NaN
# ...

# %%
df_final=pd.DataFrame(df_final)
df_final
# Out:
#     Year      Month        Total  ...        M48        M49       M50
# 0   2017      April  11542000.00  ...  212570.81  297109.46  101871.0
# 1   2017        May  12027000.00  ...  300540.44   64644.00       NaN
# 2   2017       June  13457000.00  ...   82643.00        NaN       NaN
# 3   2017       July  14307300.00  ...        NaN        NaN       NaN
# 4   2017     August  14250501.00  ...        NaN        NaN       NaN
# 5   2017  September  14623134.28  ...        NaN        NaN       NaN
# 6   2017    October  13481500.00  ...        NaN        NaN       NaN
# 7   2017   November  15395600.00  ...        NaN        NaN       NaN
# 8   2017   December  14634000.00  ...        NaN        NaN       NaN
# 9   2018    January  16132700.00  ...        NaN        NaN       NaN
# 10  2018   February  15558000.00  ...        NaN        NaN       NaN
# 11  2018      March  17489500.00  ...        NaN        NaN       NaN
# ...

# %%
df1=df[df['Occurence']==1]

# %%
df1
# Out:
#         trainer_ID  trainee_ID  ... Diff_in_months Occurence
# 0             1545       30995  ...              0       1.0
# 1             1537       28443  ...              0       1.0
# 2              117       31054  ...              0       1.0
# 3              562       32095  ...              0       1.0
# 4              562       17351  ...              0       1.0
# ...            ...         ...  ...            ...       ...
# 178044        2560     1143869  ...              0       1.0
# 178045        2491     1368501  ...              0       1.0
# 178047        2131     1512900  ...              0       1.0
# 178050        2731      972010  ...              0       1.0
# 178052        2589     1177730  ...              0       1.0
#
# [113801 rows x 15 columns]

# %%
pivot2 = df1.pivot_table(index=['YearOfFt','MonthOfFt'], columns=['Diff_in_months'],values=['pack_price'], aggfunc='sum')
pivot2=pivot2.reindex(months,level=1)
pivot2=pivot2.reset_index()

# %%
pivot2
# Out:
#                YearOfFt  MonthOfFt   pack_price
# Diff_in_months                                0
# 0                  2017      April  11498000.00
# 1                  2017        May  12015000.00
# 2                  2017       June  13443000.00
# 3                  2017       July  14159300.00
# 4                  2017     August  14199501.00
# 5                  2017  September  14569134.28
# 6                  2017    October  13395500.00
# 7                  2017   November  15182600.00
# 8                  2017   December  14598000.00
# 9                  2018    January  16125700.00
# 10                 2018   February  15319000.00
# 11                 2018      March  17155500.00
# 12                 2018      April  17943002.00
# 13                 2018        May  17841000.00
# 14                 2018       June  17967000.00
# 15                 2018       July  18406100.00
# 16                 2018     August  19493100.00
# 17                 2018  September  16691304.00
# ...

# %%
columns=['Year','Month','Fresh']

# %%
pivot2.columns=[col for col in columns]

# %%
pivot2
# Out:
#     Year      Month        Fresh
# 0   2017      April  11498000.00
# 1   2017        May  12015000.00
# 2   2017       June  13443000.00
# 3   2017       July  14159300.00
# 4   2017     August  14199501.00
# 5   2017  September  14569134.28
# 6   2017    October  13395500.00
# 7   2017   November  15182600.00
# 8   2017   December  14598000.00
# 9   2018    January  16125700.00
# 10  2018   February  15319000.00
# 11  2018      March  17155500.00
# 12  2018      April  17943002.00
# 13  2018        May  17841000.00
# 14  2018       June  17967000.00
# 15  2018       July  18406100.00
# 16  2018     August  19493100.00
# 17  2018  September  16691304.00
# 18  2018    October  14344200.00
# 19  2018   November  12839550.00
# 20  2018   December  14563057.50
# 21  2019    January  15545000.00
# 22  2019   February  13580969.00
# 23  2019      March  14857669.00
# 24  2019      April  13421374.00
# 25  2019        May  17018675.50
# 26  2019       June  20104869.00
# ...

# %%
pivot2=pd.DataFrame(pivot2)

# %%
pivot2
# Out:
#     Year      Month        Fresh
# 0   2017      April  11498000.00
# 1   2017        May  12015000.00
# 2   2017       June  13443000.00
# 3   2017       July  14159300.00
# 4   2017     August  14199501.00
# 5   2017  September  14569134.28
# 6   2017    October  13395500.00
# 7   2017   November  15182600.00
# 8   2017   December  14598000.00
# 9   2018    January  16125700.00
# 10  2018   February  15319000.00
# 11  2018      March  17155500.00
# 12  2018      April  17943002.00
# 13  2018        May  17841000.00
# 14  2018       June  17967000.00
# 15  2018       July  18406100.00
# 16  2018     August  19493100.00
# 17  2018  September  16691304.00
# 18  2018    October  14344200.00
# 19  2018   November  12839550.00
# 20  2018   December  14563057.50
# 21  2019    January  15545000.00
# 22  2019   February  13580969.00
# 23  2019      March  14857669.00
# 24  2019      April  13421374.00
# 25  2019        May  17018675.50
# 26  2019       June  20104869.00
# ...

# %%
res=pivot2['Fresh'].tolist()

# %%
res
# Out:
# [11498000.0,
#  12015000.0,
#  13443000.0,
#  14159300.0,
#  14199501.0,
#  14569134.28,
#  13395500.0,
#  15182600.0,
#  14598000.0,
#  16125700.0,
#  15319000.0,
#  17155500.0,
#  17943002.0,
#  17841000.0,
#  17967000.0,
#  18406100.0,
#  19493100.0,
#  16691304.0,
#  14344200.0,
#  12839550.0,
#  14563057.5,
#  15545000.0,
#  13580969.0,
#  14857669.0,
#  13421374.0,
#  17018675.5,
#  20104869.0,
#  21058146.0,
#  20513520.5,
#  19090014.0,
#  15630066.0,
#  17534570.0,
#  19646217.5,
#  22306928.5,
#  17596813.0,
#  13290393.0,
#  10966269.0,
#  17061856.43,
#  22758102.0,
#  31208973.5,
#  35861201.0,
#  36814927.0,
#  34041063.5,
#  32156444.5,
#  35907249.0,
#  43059701.0,
#  35313347.0,
#  39700640.64999997,
#  37499706.03999998,
#  40494284.07999999,
#  9959024.869999995]

# %%
df_final.insert(loc=3, column='Fresh', value=res)

# %%
df_final
# Out:
#     Year      Month        Total  ...        M48        M49       M50
# 0   2017      April  11542000.00  ...  212570.81  297109.46  101871.0
# 1   2017        May  12027000.00  ...  300540.44   64644.00       NaN
# 2   2017       June  13457000.00  ...   82643.00        NaN       NaN
# 3   2017       July  14307300.00  ...        NaN        NaN       NaN
# 4   2017     August  14250501.00  ...        NaN        NaN       NaN
# 5   2017  September  14623134.28  ...        NaN        NaN       NaN
# 6   2017    October  13481500.00  ...        NaN        NaN       NaN
# 7   2017   November  15395600.00  ...        NaN        NaN       NaN
# 8   2017   December  14634000.00  ...        NaN        NaN       NaN
# 9   2018    January  16132700.00  ...        NaN        NaN       NaN
# 10  2018   February  15558000.00  ...        NaN        NaN       NaN
# 11  2018      March  17489500.00  ...        NaN        NaN       NaN
# ...

# %%
df_final.insert(loc=4, column='M0', value=(df_final['Total']-df_final['Fresh']))

# %%
df_final
# Out:
#     Year      Month        Total  ...        M48        M49       M50
# 0   2017      April  11542000.00  ...  212570.81  297109.46  101871.0
# 1   2017        May  12027000.00  ...  300540.44   64644.00       NaN
# 2   2017       June  13457000.00  ...   82643.00        NaN       NaN
# 3   2017       July  14307300.00  ...        NaN        NaN       NaN
# 4   2017     August  14250501.00  ...        NaN        NaN       NaN
# 5   2017  September  14623134.28  ...        NaN        NaN       NaN
# 6   2017    October  13481500.00  ...        NaN        NaN       NaN
# 7   2017   November  15395600.00  ...        NaN        NaN       NaN
# 8   2017   December  14634000.00  ...        NaN        NaN       NaN
# 9   2018    January  16132700.00  ...        NaN        NaN       NaN
# 10  2018   February  15558000.00  ...        NaN        NaN       NaN
# 11  2018      March  17489500.00  ...        NaN        NaN       NaN
# ...

# %%
df_final.to_csv('Revenue_cohort_check_3.csv',index=False)

# %% [markdown]
# # Transaction Cohort

# %%
pivot_tran = df.pivot_table(index=['YearOfFt','MonthOfFt'], columns=['Diff_in_months'],values=['trainee_ID'], aggfunc='count')
pivot_tran
# Out:
#                    trainee_ID                      ...
# Diff_in_months             0     1      2      3   ...    47    48    49   50
# YearOfFt MonthOfFt                                 ...
# 2017     April         1378.0   2.0   70.0  104.0  ...  25.0  21.0  25.0  5.0
#          August        1634.0   6.0   75.0  116.0  ...   NaN   NaN   NaN  NaN
#          December      1810.0   3.0   54.0  175.0  ...   NaN   NaN   NaN  NaN
#          July          1618.0   5.0   73.0  181.0  ...   3.0   NaN   NaN  NaN
#          June          1681.0   7.0   50.0  170.0  ...  36.0   8.0   NaN  NaN
#          May           1459.0   6.0   38.0  130.0  ...  23.0  25.0   7.0  NaN
#          November      1810.0   5.0   74.0  156.0  ...   NaN   NaN   NaN  NaN
#          October       1567.0   2.0  136.0  116.0  ...   NaN   NaN   NaN  NaN
#          September     1677.0   5.0   61.0  153.0  ...   NaN   NaN   NaN  NaN
# 2018     April         2213.0   5.0   91.0  233.0  ...   NaN   NaN   NaN  NaN
# ...

# %%
months=['January', 'February','March','April','May','June','July','August','September','October','November','December']

df_final_tran=pivot_tran.reindex(months,level=1)

df_final_tran=df_final_tran.reset_index()
df_final_tran
# Out:
#                YearOfFt  MonthOfFt trainee_ID        ...
# Diff_in_months                              0     1  ...    47    48    49   50
# 0                  2017      April     1378.0   2.0  ...  25.0  21.0  25.0  5.0
# 1                  2017        May     1459.0   6.0  ...  23.0  25.0   7.0  NaN
# 2                  2017       June     1681.0   7.0  ...  36.0   8.0   NaN  NaN
# 3                  2017       July     1618.0   5.0  ...   3.0   NaN   NaN  NaN
# 4                  2017     August     1634.0   6.0  ...   NaN   NaN   NaN  NaN
# 5                  2017  September     1677.0   5.0  ...   NaN   NaN   NaN  NaN
# 6                  2017    October     1567.0   2.0  ...   NaN   NaN   NaN  NaN
# 7                  2017   November     1810.0   5.0  ...   NaN   NaN   NaN  NaN
# 8                  2017   December     1810.0   3.0  ...   NaN   NaN   NaN  NaN
# 9                  2018    January     1920.0   1.0  ...   NaN   NaN   NaN  NaN
# ...

# %%
columns_2=[]
columns_2.append('Year')
columns_2.append('Month')
columns_2.append('Total')

max_value=df['Diff_in_months'].max()
print(columns_2,end='\n')
print(max_value)


for i in range(1, max_value+1):
  columns_2.append("M"+str(i))
columns_2
# Out:
# ['Year', 'Month', 'Total']
# 50
# ['Year',
#  'Month',
#  'Total',
#  'M1',
#  'M2',
#  'M3',
#  'M4',
#  'M5',
#  'M6',
#  'M7',
#  'M8',
#  'M9',
#  'M10',
#  'M11',
#  'M12',
#  'M13',
#  'M14',
#  'M15',
#  'M16',
#  'M17',
#  'M18',
#  'M19',
#  'M20',
#  'M21',
#  'M22',
#  'M23',
#  'M24',
#  'M25',
#  'M26',
#  'M27',
#  'M28',
#  'M29',
#  'M30',
#  'M31',
#  'M32',
#  'M33',
#  'M34',
#  'M35',
#  'M36',
#  'M37',
#  'M38',
#  'M39',
#  'M40',
#  'M41',
#  'M42',
#  'M43',
#  'M44',
#  'M45',
#  'M46',
#  'M47',
#  'M48',
#  'M49',
#  'M50']

# %%
df_final_tran.columns=[col for col in columns_2]
df_final_tran
# Out:
#     Year      Month   Total    M1     M2  ...   M46   M47   M48   M49  M50
# 0   2017      April  1378.0   2.0   70.0  ...  17.0  25.0  21.0  25.0  5.0
# 1   2017        May  1459.0   6.0   38.0  ...  32.0  23.0  25.0   7.0  NaN
# 2   2017       June  1681.0   7.0   50.0  ...  17.0  36.0   8.0   NaN  NaN
# 3   2017       July  1618.0   5.0   73.0  ...  35.0   3.0   NaN   NaN  NaN
# 4   2017     August  1634.0   6.0   75.0  ...   8.0   NaN   NaN   NaN  NaN
# 5   2017  September  1677.0   5.0   61.0  ...   NaN   NaN   NaN   NaN  NaN
# 6   2017    October  1567.0   2.0  136.0  ...   NaN   NaN   NaN   NaN  NaN
# 7   2017   November  1810.0   5.0   74.0  ...   NaN   NaN   NaN   NaN  NaN
# 8   2017   December  1810.0   3.0   54.0  ...   NaN   NaN   NaN   NaN  NaN
# 9   2018    January  1920.0   1.0  103.0  ...   NaN   NaN   NaN   NaN  NaN
# 10  2018   February  1858.0   6.0   74.0  ...   NaN   NaN   NaN   NaN  NaN
# ...

# %%
df1=df[df['Occurence']==1]


pivot_tran_Occ_1= df1.pivot_table(index=['YearOfFt','MonthOfFt'], columns=['Diff_in_months'],values=['trainee_ID'], aggfunc='count')
pivot_tran_Occ_1=pivot_tran_Occ_1.reindex(months,level=1)
pivot_tran_Occ_1=pivot_tran_Occ_1.reset_index()
pivot_tran_Occ_1
# Out:
#                YearOfFt  MonthOfFt trainee_ID
# Diff_in_months                              0
# 0                  2017      April       1373
# 1                  2017        May       1457
# 2                  2017       June       1679
# 3                  2017       July       1598
# 4                  2017     August       1629
# 5                  2017  September       1671
# 6                  2017    October       1562
# 7                  2017   November       1794
# 8                  2017   December       1806
# 9                  2018    January       1919
# 10                 2018   February       1835
# 11                 2018      March       2097
# 12                 2018      April       2204
# 13                 2018        May       2093
# 14                 2018       June       2118
# 15                 2018       July       2204
# 16                 2018     August       2121
# 17                 2018  September       1827
# ...

# %%
columns=['Year','Month','Fresh']

pivot_tran_Occ_1.columns=[col for col in columns]
pivot_tran_Occ_1=pd.DataFrame(pivot_tran_Occ_1)
pivot_tran_Occ_1
# Out:
#     Year      Month  Fresh
# 0   2017      April   1373
# 1   2017        May   1457
# 2   2017       June   1679
# 3   2017       July   1598
# 4   2017     August   1629
# 5   2017  September   1671
# 6   2017    October   1562
# 7   2017   November   1794
# 8   2017   December   1806
# 9   2018    January   1919
# 10  2018   February   1835
# 11  2018      March   2097
# 12  2018      April   2204
# 13  2018        May   2093
# 14  2018       June   2118
# 15  2018       July   2204
# 16  2018     August   2121
# 17  2018  September   1827
# 18  2018    October   1572
# 19  2018   November   1417
# 20  2018   December   1674
# 21  2019    January   1652
# 22  2019   February   1474
# 23  2019      March   1632
# 24  2019      April   1441
# 25  2019        May   1819
# 26  2019       June   2112
# 27  2019       July   2260
# 28  2019     August   2171
# 29  2019  September   1951
# 30  2019    October   1567
# 31  2019   November   1797
# 32  2019   December   2128
# ...

# %%
res=pivot_tran_Occ_1['Fresh'].tolist()

df_final_tran.insert(loc=3, column='Fresh', value=res)
df_final_tran
# Out:
#     Year      Month   Total  Fresh    M1  ...   M46   M47   M48   M49  M50
# 0   2017      April  1378.0   1373   2.0  ...  17.0  25.0  21.0  25.0  5.0
# 1   2017        May  1459.0   1457   6.0  ...  32.0  23.0  25.0   7.0  NaN
# 2   2017       June  1681.0   1679   7.0  ...  17.0  36.0   8.0   NaN  NaN
# 3   2017       July  1618.0   1598   5.0  ...  35.0   3.0   NaN   NaN  NaN
# 4   2017     August  1634.0   1629   6.0  ...   8.0   NaN   NaN   NaN  NaN
# 5   2017  September  1677.0   1671   5.0  ...   NaN   NaN   NaN   NaN  NaN
# 6   2017    October  1567.0   1562   2.0  ...   NaN   NaN   NaN   NaN  NaN
# 7   2017   November  1810.0   1794   5.0  ...   NaN   NaN   NaN   NaN  NaN
# 8   2017   December  1810.0   1806   3.0  ...   NaN   NaN   NaN   NaN  NaN
# 9   2018    January  1920.0   1919   1.0  ...   NaN   NaN   NaN   NaN  NaN
# 10  2018   February  1858.0   1835   6.0  ...   NaN   NaN   NaN   NaN  NaN
# ...

# %%
df_final_tran.insert(loc=4, column='M0', value=(df_final_tran['Total']-df_final_tran['Fresh']))
df_final_tran
# Out:
#     Year      Month   Total  Fresh    M0  ...   M46   M47   M48   M49  M50
# 0   2017      April  1378.0   1373   5.0  ...  17.0  25.0  21.0  25.0  5.0
# 1   2017        May  1459.0   1457   2.0  ...  32.0  23.0  25.0   7.0  NaN
# 2   2017       June  1681.0   1679   2.0  ...  17.0  36.0   8.0   NaN  NaN
# 3   2017       July  1618.0   1598  20.0  ...  35.0   3.0   NaN   NaN  NaN
# 4   2017     August  1634.0   1629   5.0  ...   8.0   NaN   NaN   NaN  NaN
# 5   2017  September  1677.0   1671   6.0  ...   NaN   NaN   NaN   NaN  NaN
# 6   2017    October  1567.0   1562   5.0  ...   NaN   NaN   NaN   NaN  NaN
# 7   2017   November  1810.0   1794  16.0  ...   NaN   NaN   NaN   NaN  NaN
# 8   2017   December  1810.0   1806   4.0  ...   NaN   NaN   NaN   NaN  NaN
# 9   2018    January  1920.0   1919   1.0  ...   NaN   NaN   NaN   NaN  NaN
# 10  2018   February  1858.0   1835  23.0  ...   NaN   NaN   NaN   NaN  NaN
# ...

# %%
df_final_tran.to_csv('Transaction_cohort_check_3.csv',index=False)

# %% [markdown]
# # Unique User Cohort

# %%
df_Occ_2=df[df['Occurence']==2]
pivot_tran_Occ_2 = df_Occ_2.pivot_table(index=['YearOfFt','MonthOfFt'], columns=['Diff_in_months'],values=['trainee_ID'], aggfunc='count')
pivot_tran_Occ_2
# Out:
#                    trainee_ID                      ...
# Diff_in_months             0     1      2      3   ...   47   48   49   50
# YearOfFt MonthOfFt                                 ...
# 2017     April            5.0   2.0   70.0  102.0  ...  1.0  1.0  4.0  1.0
#          August           5.0   6.0   74.0  116.0  ...  NaN  NaN  NaN  NaN
#          December         4.0   3.0   54.0  172.0  ...  NaN  NaN  NaN  NaN
#          July            20.0   5.0   70.0  180.0  ...  NaN  NaN  NaN  NaN
#          June             2.0   7.0   50.0  169.0  ...  5.0  1.0  NaN  NaN
#          May              2.0   6.0   38.0  129.0  ...  5.0  3.0  3.0  NaN
#          November        16.0   3.0   73.0  153.0  ...  NaN  NaN  NaN  NaN
#          October          5.0   2.0  135.0  116.0  ...  NaN  NaN  NaN  NaN
#          September        6.0   5.0   61.0  150.0  ...  NaN  NaN  NaN  NaN
# 2018     April            8.0   5.0   89.0  232.0  ...  NaN  NaN  NaN  NaN
# ...

# %%
months=['January', 'February','March','April','May','June','July','August','September','October','November','December']

df_final_tran=pivot_tran.reindex(months,level=1)

df_final_tran=df_final_tran.reset_index()
df_final_tran
# Out:
#                YearOfFt  MonthOfFt trainee_ID        ...
# Diff_in_months                              0     1  ...    47    48    49   50
# 0                  2017      April     1378.0   2.0  ...  25.0  21.0  25.0  5.0
# 1                  2017        May     1459.0   6.0  ...  23.0  25.0   7.0  NaN
# 2                  2017       June     1681.0   7.0  ...  36.0   8.0   NaN  NaN
# 3                  2017       July     1618.0   5.0  ...   3.0   NaN   NaN  NaN
# 4                  2017     August     1634.0   6.0  ...   NaN   NaN   NaN  NaN
# 5                  2017  September     1677.0   5.0  ...   NaN   NaN   NaN  NaN
# 6                  2017    October     1567.0   2.0  ...   NaN   NaN   NaN  NaN
# 7                  2017   November     1810.0   5.0  ...   NaN   NaN   NaN  NaN
# 8                  2017   December     1810.0   3.0  ...   NaN   NaN   NaN  NaN
# 9                  2018    January     1920.0   1.0  ...   NaN   NaN   NaN  NaN
# ...

# %%
columns_3=[]
columns_3.append('Year')
columns_3.append('Month')
columns_3.append('Total')

max_value=df['Diff_in_months'].max()
print(columns_3,end='\n')
print(max_value)


for i in range(1, max_value+1):
  columns_3.append("M"+str(i))
columns_3
# Out:
# ['Year', 'Month', 'Total']
# 50
# ['Year',
#  'Month',
#  'Total',
#  'M1',
#  'M2',
#  'M3',
#  'M4',
#  'M5',
#  'M6',
#  'M7',
#  'M8',
#  'M9',
#  'M10',
#  'M11',
#  'M12',
#  'M13',
#  'M14',
#  'M15',
#  'M16',
#  'M17',
#  'M18',
#  'M19',
#  'M20',
#  'M21',
#  'M22',
#  'M23',
#  'M24',
#  'M25',
#  'M26',
#  'M27',
#  'M28',
#  'M29',
#  'M30',
#  'M31',
#  'M32',
#  'M33',
#  'M34',
#  'M35',
#  'M36',
#  'M37',
#  'M38',
#  'M39',
#  'M40',
#  'M41',
#  'M42',
#  'M43',
#  'M44',
#  'M45',
#  'M46',
#  'M47',
#  'M48',
#  'M49',
#  'M50']

# %%
df_final_tran.columns=[col for col in columns_3]
df_final_tran
# Out:
#     Year      Month   Total    M1     M2  ...   M46   M47   M48   M49  M50
# 0   2017      April  1378.0   2.0   70.0  ...  17.0  25.0  21.0  25.0  5.0
# 1   2017        May  1459.0   6.0   38.0  ...  32.0  23.0  25.0   7.0  NaN
# 2   2017       June  1681.0   7.0   50.0  ...  17.0  36.0   8.0   NaN  NaN
# 3   2017       July  1618.0   5.0   73.0  ...  35.0   3.0   NaN   NaN  NaN
# 4   2017     August  1634.0   6.0   75.0  ...   8.0   NaN   NaN   NaN  NaN
# 5   2017  September  1677.0   5.0   61.0  ...   NaN   NaN   NaN   NaN  NaN
# 6   2017    October  1567.0   2.0  136.0  ...   NaN   NaN   NaN   NaN  NaN
# 7   2017   November  1810.0   5.0   74.0  ...   NaN   NaN   NaN   NaN  NaN
# 8   2017   December  1810.0   3.0   54.0  ...   NaN   NaN   NaN   NaN  NaN
# 9   2018    January  1920.0   1.0  103.0  ...   NaN   NaN   NaN   NaN  NaN
# 10  2018   February  1858.0   6.0   74.0  ...   NaN   NaN   NaN   NaN  NaN
# ...

# %%
df1=df[df['Occurence']==1]


pivot_tran_Occ_1= df1.pivot_table(index=['YearOfFt','MonthOfFt'], columns=['Diff_in_months'],values=['trainee_ID'], aggfunc='count')
pivot_tran_Occ_1=pivot_tran_Occ_1.reindex(months,level=1)
pivot_tran_Occ_1=pivot_tran_Occ_1.reset_index()
pivot_tran_Occ_1
# Out:
#                YearOfFt  MonthOfFt trainee_ID
# Diff_in_months                              0
# 0                  2017      April       1373
# 1                  2017        May       1457
# 2                  2017       June       1679
# 3                  2017       July       1598
# 4                  2017     August       1629
# 5                  2017  September       1671
# 6                  2017    October       1562
# 7                  2017   November       1794
# 8                  2017   December       1806
# 9                  2018    January       1919
# 10                 2018   February       1835
# 11                 2018      March       2097
# 12                 2018      April       2204
# 13                 2018        May       2093
# 14                 2018       June       2118
# 15                 2018       July       2204
# 16                 2018     August       2121
# 17                 2018  September       1827
# ...

# %%
columns=['Year','Month','Fresh']

pivot_tran_Occ_1.columns=[col for col in columns]
pivot_tran_Occ_1=pd.DataFrame(pivot_tran_Occ_1)
pivot_tran_Occ_1
# Out:
#     Year      Month  Fresh
# 0   2017      April   1373
# 1   2017        May   1457
# 2   2017       June   1679
# 3   2017       July   1598
# 4   2017     August   1629
# 5   2017  September   1671
# 6   2017    October   1562
# 7   2017   November   1794
# 8   2017   December   1806
# 9   2018    January   1919
# 10  2018   February   1835
# 11  2018      March   2097
# 12  2018      April   2204
# 13  2018        May   2093
# 14  2018       June   2118
# 15  2018       July   2204
# 16  2018     August   2121
# 17  2018  September   1827
# 18  2018    October   1572
# 19  2018   November   1417
# 20  2018   December   1674
# 21  2019    January   1652
# 22  2019   February   1474
# 23  2019      March   1632
# 24  2019      April   1441
# 25  2019        May   1819
# 26  2019       June   2112
# 27  2019       July   2260
# 28  2019     August   2171
# 29  2019  September   1951
# 30  2019    October   1567
# 31  2019   November   1797
# 32  2019   December   2128
# ...

# %%
res=pivot_tran_Occ_1['Fresh'].tolist()

df_final_tran.insert(loc=3, column='Fresh', value=pd.Series(res))
df_final_tran
# Out:
#     Year      Month   Total  Fresh    M1  ...   M46   M47   M48   M49  M50
# 0   2017      April  1378.0   1373   2.0  ...  17.0  25.0  21.0  25.0  5.0
# 1   2017        May  1459.0   1457   6.0  ...  32.0  23.0  25.0   7.0  NaN
# 2   2017       June  1681.0   1679   7.0  ...  17.0  36.0   8.0   NaN  NaN
# 3   2017       July  1618.0   1598   5.0  ...  35.0   3.0   NaN   NaN  NaN
# 4   2017     August  1634.0   1629   6.0  ...   8.0   NaN   NaN   NaN  NaN
# 5   2017  September  1677.0   1671   5.0  ...   NaN   NaN   NaN   NaN  NaN
# 6   2017    October  1567.0   1562   2.0  ...   NaN   NaN   NaN   NaN  NaN
# 7   2017   November  1810.0   1794   5.0  ...   NaN   NaN   NaN   NaN  NaN
# 8   2017   December  1810.0   1806   3.0  ...   NaN   NaN   NaN   NaN  NaN
# 9   2018    January  1920.0   1919   1.0  ...   NaN   NaN   NaN   NaN  NaN
# 10  2018   February  1858.0   1835   6.0  ...   NaN   NaN   NaN   NaN  NaN
# ...

# %%
df_final_tran.drop('Total',axis=1,inplace=True)

# %%
df_final_tran
# Out:
#     Year      Month  Fresh    M1     M2  ...   M46   M47   M48   M49  M50
# 0   2017      April   1373   2.0   70.0  ...  17.0  25.0  21.0  25.0  5.0
# 1   2017        May   1457   6.0   38.0  ...  32.0  23.0  25.0   7.0  NaN
# 2   2017       June   1679   7.0   50.0  ...  17.0  36.0   8.0   NaN  NaN
# 3   2017       July   1598   5.0   73.0  ...  35.0   3.0   NaN   NaN  NaN
# 4   2017     August   1629   6.0   75.0  ...   8.0   NaN   NaN   NaN  NaN
# 5   2017  September   1671   5.0   61.0  ...   NaN   NaN   NaN   NaN  NaN
# 6   2017    October   1562   2.0  136.0  ...   NaN   NaN   NaN   NaN  NaN
# 7   2017   November   1794   5.0   74.0  ...   NaN   NaN   NaN   NaN  NaN
# 8   2017   December   1806   3.0   54.0  ...   NaN   NaN   NaN   NaN  NaN
# 9   2018    January   1919   1.0  103.0  ...   NaN   NaN   NaN   NaN  NaN
# 10  2018   February   1835   6.0   74.0  ...   NaN   NaN   NaN   NaN  NaN
# 11  2018      March   2097  14.0   80.0  ...   NaN   NaN   NaN   NaN  NaN
# ...

# %%
df_final_tran.to_csv('Unique_user.csv',index=False)
